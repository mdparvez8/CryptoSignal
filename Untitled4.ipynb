# %%
import pandas as pd
import streamlit as st
import datetime as dt
import numpy as np

# %%
from sqlalchemy import create_engine

# %%
engine=create_engine('sqlite:///cryptoDB.db')

# %%
symbols=pd.read_sql('SELECT name FROM sqlite_master WHERE type="table"',engine).name.to_list()

# %%
symbols
# Out:
# ['BTCUSDT',
#  'ETHUSDT',
#  'BNBUSDT',
#  'NEOUSDT',
#  'LTCUSDT',
#  'ADAUSDT',
#  'XRPUSDT',
#  'TUSDUSDT',
#  'XLMUSDT',
#  'TRXUSDT',
#  'VETUSDT',
#  'USDCUSDT',
#  'LINKUSDT',
#  'WAVESUSDT',
#  'HOTUSDT',
#  'ZILUSDT',
#  'ZRXUSDT',
#  'FETUSDT',
#  'DASHUSDT',
#  'THETAUSDT',
#  'MATICUSDT',
#  'ATOMUSDT',
#  'ONEUSDT',
#  'ALGOUSDT',
#  'DUSKUSDT',
#  'ANKRUSDT',
#  'CHZUSDT',
#  'BUSDUSDT',
#  'RVNUSDT',
#  'FTTUSDT',
#  'COTIUSDT',
#  'DATAUSDT',
#  'SOLUSDT',
#  'CTSIUSDT',
#  'HIVEUSDT',
#  'CHRUSDT',
#  'STMXUSDT',
#  'KNCUSDT',
#  'LRCUSDT',
#  'PNTUSDT',
#  'COMPUSDT',
#  'ETHDOWNUSDT',
#  'STORJUSDT',
#  'MANAUSDT',
#  'YFIUSDT',
#  'SANDUSDT',
#  'LUNAUSDT',
#  'EGLDUSDT',
#  'UMAUSDT',
#  'UNIUSDT',
#  'AVAXUSDT',
#  'HNTUSDT',
#  'AAVEUSDT',
#  'NEARUSDT',
#  'AXSUSDT',
#  'UNFIUSDT',
#  '1INCHUSDT',
#  'REEFUSDT',
#  'CAKEUSDT',
#  'CFXUSDT',
#  'PUNDIXUSDT',
#  'TLMUSDT',
#  'BTGUSDT',
#  'SLPUSDT',
#  'SHIBUSDT',
#  'ICPUSDT',
#  'DEXEUSDT',
#  'GNOUSDT',
#  'IDEXUSDT',
#  'GALAUSDT',
#  'DARUSDT',
#  'KP3RUSDT',
#  'JASMYUSDT',
#  'HIGHUSDT',
#  'BTTCUSDT',
#  'ACAUSDT',
#  'TUSDT',
#  'GMTUSDT',
#  'APEUSDT',
#  'IOTAUSDT',
#  'ETCUSDT',
#  'BATUSDT',
#  'MITHUSDT',
#  'DOGEUSDT',
#  'WINUSDT',
#  'STXUSDT',
#  'KAVAUSDT',
#  'VITEUSDT',
#  'ZENUSDT',
#  'SNXUSDT',
#  'GBPUSDT',
#  'SRMUSDT',
#  'CRVUSDT',
#  'DOTUSDT',
#  'SUSHIUSDT',
#  'FLMUSDT',
#  'ORNUSDT',
#  'ALPHAUSDT',
#  'AUDIOUSDT',
#  'CTKUSDT',
#  'GRTUSDT',
#  'CELOUSDT',
#  'MDXUSDT',
#  'GTCUSDT',
#  'FLOWUSDT',
#  'POLYUSDT',
#  'YGGUSDT',
#  'RNDRUSDT',
#  'FLUXUSDT',
#  'OOKIUSDT',
#  'ASTRUSDT',
#  'BSWUSDT',
#  'EOSUSDT',
#  'ONTUSDT',
#  'ZECUSDT',
#  'GTOUSDT',
#  'TOMOUSDT',
#  'DENTUSDT',
#  'DOCKUSDT',
#  'CTXCUSDT',
#  'EURUSDT',
#  'SXPUSDT',
#  'FIOUSDT',
#  'AKROUSDT',
#  'XEMUSDT',
#  'SKLUSDT',
#  'DODOUSDT',
#  'BAKEUSDT',
#  'ATAUSDT',
#  'PHAUSDT',
#  'GHSTUSDT',
#  'TRIBEUSDT',
#  'PORTOUSDT',
#  'PYRUSDT',
#  'GLMRUSDT',
#  'FTMUSDT',
#  'HBARUSDT',
#  'DREPUSDT',
#  'GXSUSDT',
#  'SCUSDT',
#  'ADAUPUSDT',
#  'DGBUSDT',
#  'RUNEUSDT',
#  'AVAUSDT',
#  'PSGUSDT',
#  'MINAUSDT',
#  'ENSUSDT',
#  'AMPUSDT',
#  'LOKAUSDT',
#  'QTUMUSDT',
#  'CELRUSDT',
#  'OMGUSDT',
#  'TFUELUSDT',
#  'WRXUSDT',
#  'MBLUSDT',
#  'ANTUSDT',
#  'FILUSDT',
#  'ROSEUSDT',
#  'TWTUSDT',
#  'EPSUSDT',
#  'FARMUSDT',
#  'DYDXUSDT',
#  'LAZIOUSDT',
#  'USTUSDT',
#  'ALPINEUSDT',
#  'ICXUSDT',
#  'COSUSDT',
#  'BCHUSDT',
#  'LINKDOWNUSDT',
#  'OXTUSDT',
#  'BICOUSDT',
#  'VOXELUSDT',
#  'COCOSUSDT',
#  'PERLUSDT',
#  'IOTXUSDT',
#  'OGNUSDT',
#  'JUVUSDT',
#  'ASRUSDT',
#  'ACMUSDT',
#  'ERNUSDT',
#  'IMXUSDT',
#  'API3USDT',
#  'IOSTUSDT',
#  'RENUSDT',
#  'TCTUSDT',
#  'AIONUSDT',
#  'STPTUSDT',
#  'VTHOUSDT',
#  'NMRUSDT',
#  'RSRUSDT',
#  'KSMUSDT',
#  'DIAUSDT',
#  'SPELLUSDT',
#  'MTLUSDT',
#  'BNTUSDT',
#  'XRPDOWNUSDT',
#  'SFPUSDT',
#  'OMUSDT',
#  'PONDUSDT',
#  'LINAUSDT',
#  'ARUSDT',
#  'POLSUSDT',
#  'MASKUSDT',
#  'KLAYUSDT',
#  'RADUSDT',
#  'PEOPLEUSDT',
#  'ANCUSDT',
#  'ENJUSDT',
#  'LINKUPUSDT',
#  'BLZUSDT',
#  'PAXGUSDT',
#  'PERPUSDT',
#  'BETAUSDT',
#  'BNXUSDT',
#  'MOVRUSDT',
#  'CITYUSDT',
#  'JOEUSDT',
#  'BALUSDT',
#  'TRXUPUSDT',
#  'XRPUPUSDT',
#  'SUNUSDT',
#  'HARDUSDT',
#  'TRUUSDT',
#  'DEGOUSDT',
#  'BARUSDT',
#  'RAYUSDT',
#  'MBOXUSDT',
#  'FXSUSDT',
#  'BANDUSDT',
#  'ARPAUSDT',
#  'RLCUSDT',
#  'BTCDOWNUSDT',
#  'MKRUSDT',
#  'JSTUSDT',
#  'OCEANUSDT',
#  'TRBUSDT',
#  'CKBUSDT',
#  'LITUSDT',
#  'ALICEUSDT',
#  'TKOUSDT',
#  'LPTUSDT',
#  'C98USDT',
#  'ALPACAUSDT',
#  'WAXPUSDT',
#  'USDPUSDT',
#  'XMRUSDT',
#  'WANUSDT',
#  'NKNUSDT',
#  'KMDUSDT',
#  'YFIIUSDT',
#  'DOTUPUSDT',
#  'INJUSDT',
#  'FISUSDT',
#  'SYSUSDT',
#  'FRONTUSDT',
#  'QIUSDT',
#  'NULSUSDT',
#  'CVCUSDT',
#  'XTZUSDT',
#  'ADADOWNUSDT',
#  'DOTDOWNUSDT',
#  'STRAXUSDT',
#  'SANTOSUSDT',
#  'KDAUSDT',
#  'WTCUSDT',
#  'REPUSDT',
#  'BURGERUSDT',
#  'XECUSDT',
#  'RAREUSDT',
#  'ONGUSDT',
#  'AUDUSDT',
#  'SUPERUSDT',
#  'CHESSUSDT',
#  'BTSUSDT',
#  'ETHUPUSDT',
#  'BNBDOWNUSDT',
#  'BELUSDT',
#  'BTCSTUSDT',
#  'XVGUSDT',
#  'POWRUSDT',
#  'MDTUSDT',
#  'REQUSDT',
#  'MCUSDT',
#  'CVXUSDT',
#  'QNTUSDT',
#  'TROYUSDT',
#  'XNOUSDT',
#  'NBSUSDT',
#  'XVSUSDT',
#  'ANYUSDT',
#  'SCRTUSDT',
#  'TVKUSDT',
#  'BONDUSDT',
#  'CVPUSDT',
#  'IRISUSDT',
#  'ELFUSDT',
#  'ARDRUSDT',
#  'WINGUSDT',
#  'FUNUSDT',
#  'AUTOUSDT',
#  'MFTUSDT',
#  'BTCUPUSDT',
#  'MIRUSDT',
#  'UTKUSDT',
#  'KEYUSDT',
#  'ATMUSDT',
#  'BADGERUSDT',
#  'LTOUSDT',
#  'ILVUSDT',
#  'AGLDUSDT',
#  'WNXMUSDT',
#  'RAMPUSDT',
#  'QUICKUSDT',
#  'WOOUSDT',
#  'CLVUSDT',
#  'FORUSDT',
#  'OGUSDT',
#  'TORNUSDT',
#  'MLNUSDT',
#  'PLAUSDT',
#  'BNBUPUSDT',
#  'VIDTUSDT',
#  'DNTUSDT',
#  'FIROUSDT',
#  'DCRUSDT',
#  'AUCTIONUSDT',
#  'ACHUSDT',
#  'BEAMUSDT',
#  'FIDAUSDT',
#  'ADXUSDT',
#  'LSKUSDT',
#  'DFUSDT',
#  'ALCXUSDT',
#  'TRXDOWNUSDT',
#  'FORTHUSDT',
#  'VGXUSDT',
#  'NBTUSDT',
#  'RIFUSDT',
#  'SUSDUSDT',
#  'BIFIUSDT',
#  'MULTIUSDT']

# %%
st.title('welcome to the live ta platform')
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
def applytechnicals(df):
    df['SMA7']=df.c.rolling(7).mean()
    df['SMA25']=df.c.rolling(25).mean()
    df.dropna(inplace=True)

# %%
def qry(symbol):
    now=dt.datetime.utcnow()
    before=now-dt.timedelta(minutes=43200)
    qry_str=f"""SELECT E,c FROM '{symbol}' WHERE E>='{before}'"""
    df=pd.read_sql(qry_str,engine)
    df.E=pd.to_datetime(df.E)
    df=df.set_index('E')
    df=df.resample('5Min').last()
    applytechnicals(df)
    df['position']=np.where(df['SMA7']>df['SMA25'],1,0)
    return df

# %%
def check():
    for symbol in symbols:
        if len(qry(symbol).position)>1:
            if qry(symbol).position[-1] and qry(symbol).position.diff()[-1]:
                st.write(symbol)

# %%
st.button('Get Live SMA_Crossover',on_click=check())
# Out:
# False

# %%
qry('BTCUSDT')
# Out:
#                             c          SMA7       SMA25  position
# E
# 2022-04-11 06:40:00  42249.12  42222.592857  42247.8608         0
# 2022-04-11 06:45:00  42317.68  42229.405714  42252.2324         0
# 2022-04-11 06:50:00  42269.13  42236.335714  42252.7592         0
# 2022-04-11 06:55:00  42250.00  42241.560000  42252.4256         0
# 2022-04-11 07:00:00  42229.78  42247.362857  42251.2396         0
# 2022-04-11 07:05:00  42202.43  42247.652857  42248.6164         0
# 2022-04-11 07:10:00  42205.80  42246.277143  42247.2964         0
# 2022-04-11 07:15:00  42207.53  42240.335714  42247.5624         0
# 2022-04-11 07:20:00  42273.80  42234.067143  42249.3992         0
# 2022-04-11 07:25:00  42329.93  42242.752857  42251.6760         0
# 2022-04-11 07:30:00  42323.16  42253.204286  42253.4948         0
# 2022-04-11 07:35:00  42277.03  42259.954286  42252.5472         1
# 2022-04-11 07:40:00  42281.30  42271.221429  42252.1568         1

# %%
# !streamlit run checkpy.py
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: checkpy.py
